# %%
import matplotlib.pyplot as plt
reducer_lst = [1,2,4,8,16,32]
time_lst = [25, 15, 10, 8, 10, 9]
plt.plot(reducer_lst, time_lst)
plt.title('Reduce time vs reducer number',fontsize=12)
plt.xlabel('number of reducers',fontsize=12)
plt.ylabel('time (s)',fontsize=12)
plt.show()
